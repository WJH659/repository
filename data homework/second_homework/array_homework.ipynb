# %%
from collections.abc import Sequence
from typing import Any
class Array:
    def __init__(self,iterable:Sequence[Any]):
        """
        有序数组初始化
        """
        self.iterable = list(iterable)
    def insert(self,element:Any) -> None:
        """
        插入元素
        element:要插入的元素
        """
        self.len=len(self.iterable)
        insert_index = self.len
        for index,value in enumerate(self.iterable):
            if element <value :
                insert_index = index
                break
        self.iterable.append("")
        for i in range(self.len,insert_index-1,-1):
            self.iterable[i]=self.iterable[i-1]
        self.iterable[insert_index]=element

# %%
array1 = [1,2,3,4,55,99,108]
array1 = Array(array1)
array1.insert(58)
print(array1.iterable)
array1.insert(185)
print(array1.iterable)
# Out:
# [1, 2, 3, 4, 55, 58, 99, 108]
# [1, 2, 3, 4, 55, 58, 99, 108, 185]

# %%
array1.insert(0)
print(array1.iterable)
# Out:
# [0, 1, 2, 3, 4, 55, 58, 99, 108, 185]
